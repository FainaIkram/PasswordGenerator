# %% [markdown]
# <a href="https://colab.research.google.com/github/FainaIkram/PasswordGenerator/blob/main/PasswordGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

print("=" * 50)
print("      RANDOM PASSWORD GENERATOR")
print("=" * 50)

while True:

    try:
        length = int(input("\nEnter password length: "))

        if length <= 0:
            print("Please enter a positive number.")
            continue

        # Letters and numbers
        characters = string.ascii_letters + string.digits

        # Generate password
        password = ""

        for i in range(length):
            password += random.choice(characters)

        print("\nGenerated Password:")
        print("-" * 30)
        print(password)
        print("-" * 30)

        choice = input("\nGenerate another password? (yes/no): ").lower()

        if choice != "yes":
            print("\nThank you for using the Password Generator!")
            break

    except ValueError:
        print("Invalid input! Please enter a numeric value.")
# Out:
# ...
#       RANDOM PASSWORD GENERATOR
# ...
#
# Enter password length: 8
#
# Generated Password:
# ------------------------------
# 8wHlulUn
# ------------------------------
#
# Generate another password? (yes/no): yes
#
# Enter password length: 10
#
# Generated Password:
# ------------------------------
# Nr3pm4zhRJ
# ------------------------------
#
# Generate another password? (yes/no): no
#
# Thank you for using the Password Generator!
